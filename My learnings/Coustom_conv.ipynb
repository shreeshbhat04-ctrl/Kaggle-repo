# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# 2026-09-18 12:13:24.483599: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-18 12:13:24.483739: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-18 12:13:24.636236: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    # ____,
    layers.Conv2D(filters=128,kernel_size=3,activation='relu', padding='same'),
    layers.Conv2D(filters=128,kernel_size=3,activation='relu', padding='same'),
    layers.MaxPool2D(),
    

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])
model.summary()

# Check your answer
q_1.check()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 128, 128, 32)      896
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 64, 32)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_8 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dense_4 (Dense)             (None, 6)                 196614
#
#  dropout_2 (Dropout)         (None, 6)                 0
#
#  dense_5 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 437453 (1.67 MB)
# Trainable params: 437453 (1.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    # YOUR CODE HERE: Add loss and metric
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
    
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789734125.218991     110 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/80 [==============================] - 21s 186ms/step - loss: 0.6846 - binary_accuracy: 0.5744 - val_loss: 0.6789 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.6722 - binary_accuracy: 0.5845 - val_loss: 0.6630 - val_binary_accuracy: 0.6023
# Epoch 3/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.6620 - binary_accuracy: 0.6007 - val_loss: 0.6562 - val_binary_accuracy: 0.6094
# Epoch 4/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.6585 - binary_accuracy: 0.6017 - val_loss: 0.6484 - val_binary_accuracy: 0.6246
# Epoch 5/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.6502 - binary_accuracy: 0.6158 - val_loss: 0.6402 - val_binary_accuracy: 0.6298
# Epoch 6/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.6415 - binary_accuracy: 0.6299 - val_loss: 0.6355 - val_binary_accuracy: 0.6290
# Epoch 7/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.6331 - binary_accuracy: 0.6346 - val_loss: 0.6304 - val_binary_accuracy: 0.6314
# Epoch 8/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6282 - binary_accuracy: 0.6398 - val_loss: 0.6236 - val_binary_accuracy: 0.6444
# Epoch 9/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.6234 - binary_accuracy: 0.6496 - val_loss: 0.6146 - val_binary_accuracy: 0.6539
# Epoch 10/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6090 - binary_accuracy: 0.6570 - val_loss: 0.6198 - val_binary_accuracy: 0.6508
# Epoch 11/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6035 - binary_accuracy: 0.6643 - val_loss: 0.5910 - val_binary_accuracy: 0.6785
# Epoch 12/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.5906 - binary_accuracy: 0.6768 - val_loss: 0.5842 - val_binary_accuracy: 0.6898
# Epoch 13/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.5747 - binary_accuracy: 0.6791 - val_loss: 0.5752 - val_binary_accuracy: 0.6991
# Epoch 14/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.5679 - binary_accuracy: 0.6928 - val_loss: 0.5589 - val_binary_accuracy: 0.7111
# Epoch 15/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.5490 - binary_accuracy: 0.7162 - val_loss: 0.5490 - val_binary_accuracy: 0.7175
# Epoch 16/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.5402 - binary_accuracy: 0.7329 - val_loss: 0.5510 - val_binary_accuracy: 0.7141
# Epoch 17/50
# 80/80 [==============================] - 5s 56ms/step - loss: 0.5237 - binary_accuracy: 0.7434 - val_loss: 0.5288 - val_binary_accuracy: 0.7379
# Epoch 18/50
# 80/80 [==============================] - 5s 56ms/step - loss: 0.5062 - binary_accuracy: 0.7520 - val_loss: 0.5134 - val_binary_accuracy: 0.7458
# Epoch 19/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.4861 - binary_accuracy: 0.7674 - val_loss: 0.4989 - val_binary_accuracy: 0.7555
# Epoch 20/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.4617 - binary_accuracy: 0.7864 - val_loss: 0.4821 - val_binary_accuracy: 0.7682
# Epoch 21/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.4452 - binary_accuracy: 0.7936 - val_loss: 0.4751 - val_binary_accuracy: 0.7721
# Epoch 22/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.4266 - binary_accuracy: 0.7977 - val_loss: 0.4612 - val_binary_accuracy: 0.7820
# Epoch 23/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.3982 - binary_accuracy: 0.8212 - val_loss: 0.4855 - val_binary_accuracy: 0.7640
# Epoch 24/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.3848 - binary_accuracy: 0.8296 - val_loss: 0.4365 - val_binary_accuracy: 0.7983
# Epoch 25/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.3540 - binary_accuracy: 0.8421 - val_loss: 0.4214 - val_binary_accuracy: 0.8086
# Epoch 26/50
# 80/80 [==============================] - 5s 56ms/step - loss: 0.3354 - binary_accuracy: 0.8569 - val_loss: 0.4346 - val_binary_accuracy: 0.8070
# Epoch 27/50
# 80/80 [==============================] - 5s 56ms/step - loss: 0.3313 - binary_accuracy: 0.8568 - val_loss: 0.4279 - val_binary_accuracy: 0.8107
# Epoch 28/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2971 - binary_accuracy: 0.8712 - val_loss: 0.4291 - val_binary_accuracy: 0.8133
# Epoch 29/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2685 - binary_accuracy: 0.8833 - val_loss: 0.4612 - val_binary_accuracy: 0.8024
# Epoch 30/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2582 - binary_accuracy: 0.8904 - val_loss: 0.4677 - val_binary_accuracy: 0.7937
# Epoch 31/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2403 - binary_accuracy: 0.8964 - val_loss: 0.5264 - val_binary_accuracy: 0.7765
# Epoch 32/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2453 - binary_accuracy: 0.8978 - val_loss: 0.6043 - val_binary_accuracy: 0.7628
# Epoch 33/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2431 - binary_accuracy: 0.8941 - val_loss: 0.4415 - val_binary_accuracy: 0.8099
# Epoch 34/50
# 80/80 [==============================] - 5s 56ms/step - loss: 0.2218 - binary_accuracy: 0.9072 - val_loss: 0.4556 - val_binary_accuracy: 0.8159
# Epoch 35/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1939 - binary_accuracy: 0.9252 - val_loss: 0.5129 - val_binary_accuracy: 0.8228
# Epoch 36/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.1843 - binary_accuracy: 0.9212 - val_loss: 0.5200 - val_binary_accuracy: 0.8287
# Epoch 37/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.1623 - binary_accuracy: 0.9338 - val_loss: 0.6748 - val_binary_accuracy: 0.8109
# Epoch 38/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1708 - binary_accuracy: 0.9310 - val_loss: 0.6367 - val_binary_accuracy: 0.8246
# Epoch 39/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.1487 - binary_accuracy: 0.9386 - val_loss: 0.6391 - val_binary_accuracy: 0.8141
# Epoch 40/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.1530 - binary_accuracy: 0.9359 - val_loss: 0.6141 - val_binary_accuracy: 0.8266
# Epoch 41/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1436 - binary_accuracy: 0.9357 - val_loss: 0.7339 - val_binary_accuracy: 0.7953
# Epoch 42/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1282 - binary_accuracy: 0.9488 - val_loss: 0.5577 - val_binary_accuracy: 0.8337
# Epoch 43/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1287 - binary_accuracy: 0.9482 - val_loss: 0.6834 - val_binary_accuracy: 0.8276
# Epoch 44/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1237 - binary_accuracy: 0.9470 - val_loss: 0.4897 - val_binary_accuracy: 0.8428
# Epoch 45/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1119 - binary_accuracy: 0.9547 - val_loss: 0.5005 - val_binary_accuracy: 0.8410
# Epoch 46/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1096 - binary_accuracy: 0.9572 - val_loss: 0.4678 - val_binary_accuracy: 0.8386
# Epoch 47/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0936 - binary_accuracy: 0.9601 - val_loss: 0.6031 - val_binary_accuracy: 0.8299
# Epoch 48/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0911 - binary_accuracy: 0.9658 - val_loss: 0.6602 - val_binary_accuracy: 0.8208
# Epoch 49/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0772 - binary_accuracy: 0.9678 - val_loss: 0.6646 - val_binary_accuracy: 0.8371
# Epoch 50/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.0644 - binary_accuracy: 0.9717 - val_loss: 0.7093 - val_binary_accuracy: 0.8460

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
